# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
districts_df = pd.read_csv('congressional_districts.csv')

# %%
districts_df.head()
# Out:
#    Unnamed: 0     CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0           0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1           1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2           2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3           3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4           4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate
# 0               532244.0    67.181406
# 1               544464.0    60.134187
# 2               516295.0    47.901103
# 3               543854.0    53.895163
# 4               515701.0    55.607416

# %%
districts_df.drop(['Unnamed: 0'], axis =1, inplace=True)

# %%
districts_df.head()
# Out:
#       CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate
# 0               532244.0    67.181406
# 1               544464.0    60.134187
# 2               516295.0    47.901103
# 3               543854.0    53.895163
# 4               515701.0    55.607416

# %%
districts_df['CD'] = districts_df['CD'].apply(lambda x: x.upper())

# %%
districts_df.head()
# Out:
#       CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate
# 0               532244.0    67.181406
# 1               544464.0    60.134187
# 2               516295.0    47.901103
# 3               543854.0    53.895163
# 4               515701.0    55.607416

# %%
districts_df['CD'] = districts_df['CD'].apply(lambda x: x.replace('_', '-'))

# %%
districts_df.head()
# Out:
#       CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate
# 0               532244.0    67.181406
# 1               544464.0    60.134187
# 2               516295.0    47.901103
# 3               543854.0    53.895163
# 4               515701.0    55.607416

# %%
districts_df['CD'][0] = 'AK-AL'

# %%
districts_df['CD'][86] = 'DE-AL'

# %%
districts_df['CD'][232] = 'MT-AL'

# %%
districts_df['CD'][246] = 'ND-AL'

# %%
districts_df['CD'][351] = 'SD-AL'

# %%
districts_df['CD'][412] = 'VT-AL'

# %%
districts_df['CD'][434] = 'WY-AL'

# %%
districts_df.to_csv('congressional_districts.csv')

# %%
districts_df.head()
# Out:
#       CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate
# 0               532244.0    67.181406
# 1               544464.0    60.134187
# 2               516295.0    47.901103
# 3               543854.0    53.895163
# 4               515701.0    55.607416

# %%
density_df = pd.read_csv('citylab_cdi.csv')

# %%
density_df.head()
# Out:
#       CD             Cluster  Very low density  Low density  Medium density  \
# 0  AK-AL          Pure rural          0.482993     0.198331        0.229245
# 1  AL-01  Rural-suburban mix          0.365359     0.428878        0.197413
# 2  AL-02          Pure rural          0.535487     0.316148        0.148366
# 3  AL-03          Pure rural          0.540407     0.389348        0.065552
# 4  AL-04          Pure rural          0.695332     0.288942        0.015726
#
#    High density
# 0      0.089431
# 1      0.008350
# 2      0.000000
# 3      0.004693
# 4      0.000000

# %%
districts_df[['Very low density', 'Low density', 'Medium density', 'High density']] = density_df[['Very low density', 'Low density', 'Medium density', 'High density']]

# %%
districts_df.head()
# Out:
#       CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate  Very low density  Low density  \
# 0               532244.0    67.181406          0.482993     0.198331
# 1               544464.0    60.134187          0.365359     0.428878
# 2               516295.0    47.901103          0.535487     0.316148
# 3               543854.0    53.895163          0.540407     0.389348
# 4               515701.0    55.607416          0.695332     0.288942
#
#    Medium density  High density
# 0        0.229245      0.089431
# 1        0.197413      0.008350
# 2        0.148366      0.000000
# 3        0.065552      0.004693
# ...

# %%
districts_df['Election_Result'] = np.where(districts_df['Percentage_for_Biden']>=50.0, 'Biden', 'Trump')

# %%
districts_df.head()
# Out:
#       CD     Biden     Trump     Total  Percentage_for_Biden  \
# 0  AK-AL  153778.0  189951.0  357569.0             43.006525
# 1   AL-1  115683.0  208367.0  327409.0             35.332871
# 2   AL-2   70484.0  174437.0  247311.0             28.500148
# 3   AL-3   98663.0  191488.0  293111.0             33.660627
# 4   AL-4   49904.0  234143.0  286768.0             17.402221
#
#    Voting_Age_Population  Voting_Rate  Very low density  Low density  \
# 0               532244.0    67.181406          0.482993     0.198331
# 1               544464.0    60.134187          0.365359     0.428878
# 2               516295.0    47.901103          0.535487     0.316148
# 3               543854.0    53.895163          0.540407     0.389348
# 4               515701.0    55.607416          0.695332     0.288942
#
#    Medium density  High density Election_Result
# 0        0.229245      0.089431           Trump
# 1        0.197413      0.008350           Trump
# ...

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split

# %%
X = districts_df.drop(['Election_Result', 'CD', 'Percentage_for_Biden', 'Voting_Rate', 'Biden', 'Trump', 'Total'], axis=1)
y = districts_df['Election_Result']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = tree.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#        Biden       0.74      0.87      0.80        70
#        Trump       0.85      0.72      0.78        74
#
#     accuracy                           0.79       144
#    macro avg       0.80      0.79      0.79       144
# weighted avg       0.80      0.79      0.79       144

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[61  9]
#  [21 53]]

# %%
predictions
# Out:
# array(['Biden', 'Trump', 'Biden', 'Trump', 'Trump', 'Biden', 'Trump',
#        'Biden', 'Biden', 'Trump', 'Biden', 'Biden', 'Biden', 'Biden',
#        'Biden', 'Trump', 'Trump', 'Trump', 'Biden', 'Trump', 'Trump',
#        'Biden', 'Biden', 'Biden', 'Trump', 'Trump', 'Biden', 'Trump',
#        'Biden', 'Biden', 'Trump', 'Biden', 'Biden', 'Biden', 'Trump',
#        'Biden', 'Biden', 'Trump', 'Biden', 'Biden', 'Trump', 'Trump',
#        'Biden', 'Biden', 'Trump', 'Biden', 'Trump', 'Trump', 'Trump',
#        'Trump', 'Trump', 'Trump', 'Trump', 'Biden', 'Trump', 'Biden',
#        'Biden', 'Biden', 'Biden', 'Trump', 'Biden', 'Trump', 'Biden',
#        'Biden', 'Trump', 'Biden', 'Biden', 'Trump', 'Trump', 'Biden',
#        'Biden', 'Biden', 'Biden', 'Trump', 'Trump', 'Trump', 'Biden',
#        'Biden', 'Biden', 'Trump', 'Biden', 'Biden', 'Trump', 'Biden',
#        'Biden', 'Trump', 'Biden', 'Biden', 'Biden', 'Trump', 'Biden',
# ...

# %%
y_test
# Out:
# 280    Biden
# 78     Trump
# 113    Biden
# 253    Trump
# 324    Biden
#        ...
# 387    Trump
# 391    Trump
# 220    Biden
# 157    Trump
# 342    Biden
# Name: Election_Result, Length: 144, dtype: object

# %%
decision_tree_classifier_results_df = pd.DataFrame(predictions, y_test)

# %%
decision_tree_classifier_results_df.reset_index()
# Out:
#     Election_Result      0
# 0             Biden  Biden
# 1             Trump  Trump
# 2             Biden  Biden
# 3             Trump  Trump
# 4             Biden  Trump
# ..              ...    ...
# 139           Trump  Biden
# 140           Trump  Trump
# 141           Biden  Biden
# 142           Trump  Trump
# 143           Biden  Biden
#
# [144 rows x 2 columns]

# %% [markdown]
# The decision tree classifier was able to predict the congressional district election results with an accuracy of 82%.
